# %%
# !ollama pull llama3.2-vision
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling 11f274007f09... 100% ▕████████████████▏ 6.0 GB
# pulling ece5e659647a... 100% ▕████████████████▏ 1.9 GB
# pulling 715415638c9c... 100% ▕████████████████▏  269 B
# pulling 0b4284c1f870... 100% ▕████████████████▏ 7.7 KB
# pulling fefc914e46e6... 100% ▕████████████████▏   32 B
# pulling fbd313562bb7... 100% ▕████████████████▏  572 B
# verifying sha256 digest
# writing manifest
# success

# %%
import ollama

# %%
# !ollama pull llama3.2-vision
# Out:
# pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling 11f274007f09... 100% ▕████████████████▏ 6.0 GB
# pulling ece5e659647a... 100% ▕████████████████▏ 1.9 GB
# pulling 715415638c9c... 100% ▕████████████████▏  269 B
# pulling 0b4284c1f870... 100% ▕████████████████▏ 7.7 KB
# pulling fefc914e46e6... 100% ▕████████████████▏   32 B
# pulling fbd313562bb7... 100% ▕████████████████▏  572 B
# verifying sha256 digest
# writing manifest
# success

# %%
import ollama
import os
input_dir_path = "./screenshots_output"

if not os.path.exists(input_dir_path):
    raise ValueError(f"Directory {input_dir_path} does not exist!")
docs = []
# image_files = [f for f in os.listdir(input_dir_path) if f.endswith(".png")]
    
response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'Analyze the following screenshot from Pokémon Red and provide a detailed description. Include information on the setting, characters, and visible elements. Describe the player position, movement, and interactions. If possible, infer the context based on the surroundings. Format your response in a structured way with sections such as Environment, Characters, Actions, and Possible Context',
        'images': ["./screenshots_output/screenshot_0000.png"]
    }]
)

# %% [markdown]
# {'model': 'llama3.2-vision', 'created_at': '2025-02-27T09:31:12.256466179Z', 'message': {'role': 'assistant', 'content': 'This image contains a simple graphic of an action bar, featuring three arrows that read "ARROW_UP," "ARROW_LEFT" and "ARROW_RIGHT." The image also includes buttons, which are likely to be part of the game\'s interface. The buttons depict icons such as a shield, a health potion, a map, and possibly other items or abilities.'}, 'done_reason': 'stop', 'done': True, 'total_duration': 110686391761, 'load_duration': 7868911527, 'prompt_eval_count': 18, 'prompt_eval_duration': 87720000000, 'eval_count': 74, 'eval_duration': 15005000000}

# %%
print(response)
# Out:
# model='llama3.2-vision' created_at='2025-03-06T07:57:55.1657416Z' done=True done_reason='stop' total_duration=27839402900 load_duration=2830399400 prompt_eval_count=79 prompt_eval_duration=2851000000 eval_count=332 eval_duration=22113000000 message=Message(role='assistant', content="**Step 1: Describe the environment**\n\nThe screenshot appears to be from a video game, specifically Pokémon Red. The background is a simple, pixelated landscape with a few objects scattered around.\n\n*   There are two trees on either side of the screen.\n*   A small rock or boulder is visible in the center of the screen.\n\n**Step 2: Identify characters**\n\nThere is one character present in the screenshot:\n\n*   The player's character is standing in front of the rock, facing to the right. They appear to be a human-like figure with a backpack and a walking stick.\n\n**Step 3: Determine actions**\n\nThe player's character is currently moving to the right, as indicated by their direction and the fact that they are not interacting with any objects or characters on the screen.\n\n*   The player has not interacted with any objects or characters yet.\n*   There are no other characters present in the screenshot.\n\n**Step 4: Infer context**\n\nBased on the environment and character actions, it is likely that the player is on a journey through a forest or wilderness area. They may be exploring the area, searching for wild Pokémon, or trying to reach their destination.\n\n*   The presence of trees and rocks suggests that the player is in a natural environment.\n*   The fact that the player is moving to the right implies that they are heading towards something, possibly a town or another location.\n\nOverall, the screenshot provides a glimpse into the gameplay mechanics and setting of Pokémon Red. The player's character is able to move around and interact with their surroundings, which suggests that the game has a focus on exploration and adventure.", images=None, tool_calls=None)

# %% [markdown]
# Test for llvma 3.2

# %%
import ollama
from ollama import generate

import glob
import pandas as pd
from PIL import Image

import os
from io import BytesIO

# Load the DataFrame from a CSV file, or create a new one if the file doesn't exist
def load_or_create_dataframe(filename):
    if os.path.isfile(filename):
        df = pd.read_csv(filename)
    else:
        df = pd.DataFrame(columns=['image_file', 'description'])
    return df

df = load_or_create_dataframe('image_descriptions.csv')

def get_png_files(folder_path):
    return glob.glob(f"{folder_path}/*.png")

# get the list of image files in the folder yopu want to process
image_files = get_png_files("./screenshots_output") 
image_files.sort()

print(image_files[:20])
print(df.head())


# processing the images 
def process_image(image_file):
    print(f"\nProcessing {image_file}\n")
    with Image.open(image_file) as img:
        with BytesIO() as buffer:
            img.save(buffer, format='PNG')
            image_bytes = buffer.getvalue()

    full_response = ''
    # Generate a description of the image
    for response in generate(model='llama3.2-vision', 
                             prompt= 'describe the content following screenshot from Pokémon Red. Concise into 4-5 sentence paragraph.', 
                             images=[image_bytes], 
                             stream=True):
        # Print the response to the console and add it to the full response
        print(response['response'], end='', flush=True)
        full_response += response['response']

    # Add a new row to the DataFrame
    df.loc[len(df)] = [image_file, full_response]


for image_file in image_files:
    if image_file not in df['image_file'].values:
        process_image(image_file)

# Save the DataFrame to a CSV file
df.to_csv('image_descriptions.csv', index=False)
# Out:
# ['./screenshots_output\\screenshot_0000.png', './screenshots_output\\screenshot_0001.png', './screenshots_output\\screenshot_0002.png', './screenshots_output\\screenshot_0003.png', './screenshots_output\\screenshot_0004.png', './screenshots_output\\screenshot_0005.png', './screenshots_output\\screenshot_0006.png', './screenshots_output\\screenshot_0007.png', './screenshots_output\\screenshot_0008.png', './screenshots_output\\screenshot_0009.png', './screenshots_output\\screenshot_0010.png', './screenshots_output\\screenshot_0011.png', './screenshots_output\\screenshot_0012.png', './screenshots_output\\screenshot_0013.png', './screenshots_output\\screenshot_0014.png', './screenshots_output\\screenshot_0015.png', './screenshots_output\\screenshot_0016.png', './screenshots_output\\screenshot_0017.png', './screenshots_output\\screenshot_0018.png', './screenshots_output\\screenshot_0019.png']
# Empty DataFrame
# Columns: [image_file, description]
# Index: []
#
# Processing ./screenshots_output\screenshot_0000.png
#
# This screenshot depicts a gameplay scene from Pokémon Red, showcasing the protagonist standing in front of two trainers' desks at a Pokémon Center. The desk on the left has several items stored, including a few Poké Balls, while the one on the right is empty except for a single item.
#
# The player character appears to be engaged with the game, as indicated by their positioning and the presence of the arrow commands at the bottom of the screen. This scene likely represents an early stage in the game where players are still exploring the world and interacting with various locations.
# Processing ./screenshots_output\screenshot_0001.png
#
# The screenshot provided is a cropped section of the game, but it appears to be a menu screen in Pokémon Red. The top-left corner displays the player's current party with their respective names, types, and HP values. Below this information are two buttons, "OK" (top) and "Cancel" (bottom), which are likely used for selecting or confirming actions.
#
# *   **Player Party**
#     *   Squirtle (Water)
#         *   HP: 98/100
#     *   Bulbasaur (Grass/Poison)
#         *   HP: 87/90
#     *   Clefairy (Fairy)
#         *   HP: 93/95
#     *   Pikachu (Electric)
#         *   HP: 92/95
# *   **Menu Buttons**
#     *   OK
#     *   Cancel
# Processing ./screenshots_output\screenshot_0002.png
#
# The screenshot depicts a battle scene in Pokémon Red, where three wild Pokémon are facing off against the player's character, Pikachu. The top-left Pokémon appears to be a Rattata, while the bottom-left one is likely a Pidgey, and the top-right one could be an Ekans or Spearow. A text prompt at the bottom of the screen reads "Choose your move," indicating that the player must select from their available options, which include "Pound," "Tail Whip," and "Thunder Shock." The background of the scene is a dark, pixelated terrain, adding to the retro aesthetic of the game. Overall, the screenshot captures a moment of intense action in the Pokémon Red gameplay experience.
# Processing ./screenshots_output\screenshot_0003.png
#
# The provided image is a screenshot from the first generation of Pokémon games, specifically from the original Pokémon Red game for the Game Boy. This screenshot features a text box displaying the code 'ARROW_DOWN,' which can be used to input instructions in the game's built-in programming language called "Tetris." The Tetris editor allows players to program their Pokémon to perform specific actions and movements during battles.
#
# In this image, the player is attempting to create a script that will cause the character to move down on the screen. By entering 'ARROW_DOWN' into the Tetris editor, the player can input instructions for the game to execute. This feature allows players to customize their gameplay experience and add unique elements to their battles.
#
# The Tetris editor is a built-in feature of the Pokémon games that enables players to create complex programs using simple commands like 'ARROW_DOWN.' By combining these commands, players can create intricate scripts that control various aspects of the game, including character movements and actions. This feature adds a layer of complexity and creativity to the gameplay experience, allowing players to express themselves and showcase their skills.
#
# Overall, this screenshot provides insight into the creative possibilities offered by the Tetris editor in Pokémon Red. By utilizing this feature, players can add depth and variety to their gameplay, making each battle unique and exciting.
# Processing ./screenshots_output\screenshot_0004.png
#
# The image shows the Game & Watch screen with the "Mystery Gift" feature being used to add items to the player's game. The Mystery Gift option is available on the first floor of Lavender Town, where players can receive new and unique Pokémon and items by linking their cartridge with a second, functioning copy of Red.
#
# To access this feature, follow these steps:
#
# 1. Go to the first floor of Lavender Town.
# 2. Enter any building in the middle part of the area.
# 3. Press "A" to open the menu.
# 4. Select "Mystery Gift" from the options and press "A".
# 5. Link your cartridge with a second, functioning copy of Red.
#
# After linking, you will receive two Pokémon as gifts: Slowpoke and Haunter. The Mystery Gift feature is an essential part of the game, providing players with new and unique Pokémon to add to their team and enhance their gameplay experience.
# Processing ./screenshots_output\screenshot_0005.png
#
# The image displays a screenshot of the menu screen in the classic video game Pokémon Red, which was released for the original Game Boy console.
#
# At the top of the screen is an arrow cursor that allows players to select items from a list of options. The player can move the arrow up or down using the D-pad on their Game Boy console to navigate through the available selections.
#
# Below the arrow are three menu options: **ARROW_DOWN**, **ARROW_UP** and **ARROW_LEFT**. These menus allow players to access various features, such as viewing their current party members, checking their inventory, or accessing other game functions.
#
# The background of the screen is a light grey color with small, pixelated graphics scattered throughout. Overall, this screenshot provides a glimpse into the user interface and gameplay mechanics of Pokémon Red, showcasing how players interacted with the game on the original Game Boy console.
# Processing ./screenshots_output\screenshot_0006.png
#
# The provided image is a screenshot of the battle scene in Pokémon Red, showcasing a trainer's Pikachu facing off against an opponent's Raticate.
#
# In this battle scenario, the trainer has three active Pokémon: Pikachu (front), Squirtle (middle left), and Charmander (middle right). The opponent also has three active Pokémon: Raticate (front), Ekans (top left), and Sandshrew (bottom right).
#
# The current state of the battle is that none of the Pokémon have used any moves, with all Pokémon having full HP. This suggests that the battle has just begun.
#
# At the top-left corner of the screen, there are three arrows pointing to each active Pokémon: ARROW_LEFT, ARROW_MIDDLE, and ARROW_RIGHT. These arrows likely represent the trainer's current selection or focus on a particular Pokémon.
#
# Overall, this screenshot captures a pivotal moment in the game, where the trainer must strategically decide which Pokémon to use and when to attack to emerge victorious in the battle.
# Processing ./screenshots_output\screenshot_0007.png
#
# The image depicts a scene from the video game Pokémon Red, showcasing Professor Oak's laboratory.
#
# In this scene, the player is presented with various objects to interact with. The first object is a Poké Ball, which can be selected and used to capture wild Pokémon encountered in the overworld. Adjacent to it lies a Potion, another item that can be utilized to heal the player character during battles or when they are injured.
#
# To the right of these items is an exit door, marked by an arrow pointing left, indicating that this is one way out of the room. On the bottom row, there are two more objects: a Pokédex and an empty space with no object, represented by a blank square.
# Processing ./screenshots_output\screenshot_0008.png
#
# The image depicts a scene from Pokémon Red, showcasing a battle against an opponent's Pikachu. The player has three active Pokemon: Squirtle (front left), Charmander (middle), and Bulbasaur (back right). Notably, Squirtle is paralyzed, rendering it unable to move.
#
# **Battle Details**
#
# * Opponent's Pikachu uses Thunder Shock on Squirtle.
# * Player's next action will be crucial in determining the outcome of the battle.
# Processing ./screenshots_output\screenshot_0009.png
#
# The image shows a black-and-white screenshot of Pokémon Red, depicting a trainer's journey through the Lavender Town area. The top third of the screen displays various rooms and hallways in the town's buildings, while the bottom two-thirds showcase a map of the surrounding area.
#
# A path leading northward out of the town is visible on the right side of the image, accompanied by an arrow pointing towards the Lavender Tower in the distance. The trainer has several items stored in their bag, including Poké Balls and Potions.
#
# The screenshot also includes text at the bottom of the screen, indicating that the player can use various commands such as "Actions" and "Options." These options likely allow players to interact with characters, access menus, or perform other actions within the game.
# Processing ./screenshots_output\screenshot_0010.png
#
# The image shows a screenshot of the Pokémon Red game, featuring two trainers facing off against each other in a battle. The top trainer is on the right-hand side of the screen, while the bottom trainer is located on the left.
#
# The top trainer has three Pokémon: an Alakazam, a Persian, and an Abra. In contrast, the bottom trainer only has one Pokémon, which is an Eevee.
#
# Below the trainers' Pokémon are their respective health points (HP), with the bottom trainer's HP being significantly higher than that of the top trainer. The background of the image features a grayish color scheme, which adds to the overall atmosphere of the battle scene.
# Processing ./screenshots_output\screenshot_0011.png
#
# The provided image is a screenshot of the classic game Pokémon Red, showcasing an in-game scene featuring two characters standing side-by-side in front of a building.
#
# In the foreground, Pikachu, a small, yellow mouse-like creature with red cheeks and black eyes, stands on the left-hand side of the screen. To its right, Squirtle, a blue turtle-like Pokemon with a yellow belly and a black stripe around its neck, is visible. Both characters are facing forward towards the building.
#
# The background of the image features a gray stone wall with a large window at the center, accompanied by two smaller windows to either side. The scene appears to be set in a town or village within the game's world.
# Processing ./screenshots_output\screenshot_0012.png
#
# This image displays a screenshot of the bottom portion of the screen in Pokémon Red, showcasing the main menu.
#
# The menu is presented in black text on a white background, with four options listed: "Actions," "Bag," "PC," and "Save." The arrows are gray, allowing for easy navigation between menus.
#
# Below the menus, the text "ARROW_UP, ARROW_DOWN, BUTTON_B" is displayed in bold text, indicating that the player can use these controls to interact with the menus.
#
# The Pokémon Red logo is not visible in this image. Overall, this screenshot provides a clear view of the main menu and its associated actions.
# Processing ./screenshots_output\screenshot_0013.png
#
# The provided screenshot appears to be a Gameboy emulator of the Pokémon Red game, showcasing the main character's current location in Celadon City.
#
# In this scene, three buildings line the street in front of the player's character. The leftmost building is likely the Poké Mart, which sells items for the player's Pokémon and other useful supplies. The middle building is the Game Corner, where the player can engage in mini-games to earn money. Unfortunately, due to image quality issues, it is not possible to determine what is inside the third building.
#
# The player character stands on the street, looking towards the left side of the screen. A small amount of text at the bottom of the screen displays "BUTTON_B ARROW_RIGHT ARROW_DOWN," indicating that these are likely the controls used for navigating menus and interacting with objects in the game world.
# Processing ./screenshots_output\screenshot_0014.png
#
# The provided image is a screenshot of the Pokémon Red game, displaying the player's current party with three Pokémon.
#
# In the foreground, each Pokémon is represented by an icon showing its type: either a black Pokeball for Grass-type or a skull for Poison-type. The top row shows the first two Pokémon, while the bottom row displays the third Pokémon and the player's current item. Below the Pokémon icons, the text "Actions: BUTTON_B ARROW_RIGHT BUTTON_B" is displayed in bold font.
#
# The background of the image is white with faint black grid lines, providing a clean and simple visual representation of the game's party management interface.
# Processing ./screenshots_output\screenshot_0015.png
#
# The image presents a screenshot from Pokémon Red, featuring an in-game map with several buildings. The map is divided into two sections: the top section displays the player's current location, while the bottom section contains icons for various items and actions.
#
# In the top section, the following structures are visible:
#
# * A small house to the left of center
# * Two rows of trees behind it
# * A large building in the background, with its roof partially obscured by the edge of the screen
#
# The bottom section features an array of icons, including:
# * Poké Balls
# * Items (e.g., potions, revives)
# * Arrows pointing to the left and right sides of the map
#
# Overall, the screenshot appears to be a section of the Pokémon Red map, likely from the Viridian City area. The presence of buildings and various items suggests that this is an outdoor area with multiple locations for exploration.
# Processing ./screenshots_output\screenshot_0016.png
#
# The provided image appears to be a portion of a Pokémon game, likely Pokémon Red. The top left corner displays an arrow pointing downwards, indicating that this is the "ARROW_DOWN" command in the game's code.
#
# Below this, we see two arrows pointing towards each other, suggesting the presence of a "BELL" object, a common feature in the original Pokémon games. On the right side of the image, three arrows point to the right, and an arrow points downwards. This could be indicative of the location of items or objects within the game.
#
# At the bottom of the image, we find a faint outline of the character's sprite, possibly hinting at their position on the map. The overall design and layout suggest that this is an in-game menu or UI element, providing players with essential information about their surroundings and available actions.
# Processing ./screenshots_output\screenshot_0017.png
#
# The image features a black-and-white screenshot from Pokémon Red, showcasing a top-down view of the game's layout.
#
# On the left side of the screen is a grid pattern, while on the right side are various icons representing items and other elements. A small window at the bottom displays some text, likely indicating the player's current location or status within the game.
#
# The screenshot also features two lines of code near the top, which may be related to programming or coding for the game. Overall, this image provides a glimpse into the visual design and layout of Pokémon Red.
# Processing ./screenshots_output\screenshot_0018.png
#
# The image appears to be a screenshot from the original game "Pokémon Red" for the Game Boy, showcasing part of Professor Oak's laboratory in Pallet Town.
#
# On the left side of the screen, the player's character is seen standing next to a Poké Ball on a table. The professor can be seen to the right of this, wearing his signature lab coat and holding a Poké Ball. A small window with two Poké Balls sitting on the ledge above it is visible in the background.
#
# The top-left corner of the screen features a menu bar displaying various options, including "Pokémon," "Items," "Bag," and "Menu." The bottom of the image shows several Pokémon names listed vertically, likely representing the player's current party or available Pokémon.
# Processing ./screenshots_output\screenshot_0019.png
#
# The provided image appears to be a screenshot of Pokémon Red, showcasing a top-down view of the graphics during gameplay. The player's character is situated at the bottom center of the screen, while the opponent's character is positioned at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# ...
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls. Overall, the screenshot provides insight into the gameplay mechanics and user interface of Pokémon Red, highlighting the importance of selecting moves effectively to succeed in battle.
#
# The image shows a top-down view of the graphics during gameplay, with the player's character at the bottom center and the opponent's character at the top center. A black arrow pointing downwards within a box is displayed above the player's character, accompanied by the text "ARROW_DOWN" in the upper left-hand corner. Below this is a white bar with black text stating "ARROW_DOWN," followed by an arrow pointing to the right. The game's graphics are rendered using pixel art, characterized by its 8-bit or retro aesthetic, which was typical of early Nintendo games such as Pokémon Red.
#
# In this scene, the player has initiated combat with their opponent and is now selecting a move from their menu. The black arrow pointing downwards within the box indicates that "Down" on the controller will be used to select an option or navigate through menus. The text "ARROW_DOWN" in the upper left-hand corner serves as a reminder of this functionality, providing visual guidance for players unfamiliar with the game's controls
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 56
#      54 for image_file in image_files:
#      55     if image_file not in df['image_file'].values:
# ---> 56         process_image(image_file)
#      58 # Save the DataFrame to a CSV file
#      59 df.to_csv('image_descriptions.csv', index=False)
#
# Cell In[13], line 42, in process_image(image_file)
#      40 full_response = ''
#      41 # Generate a description of the image
# ---> 42 for response in generate(model='llama3.2-vision',
#      43                          prompt= 'Analyze the following screenshot from Pokémon Red and provide a detailed description. Concise into 4-5 sentence paragraph.',
#      44                          images=[image_bytes],
#      45                          stream=True):
#      46     # Print the response to the console and add it to the full response
#      47     print(response['response'], end='', flush=True)
#      48     full_response += response['response']
#
# File c:\Python311\Lib\site-packages\ollama\_client.py:170, in Client._request.<locals>.inner()
#     167   e.response.read()
#     168   raise ResponseError(e.response.text, e.response.status_code) from None
# --> 170 for line in r.iter_lines():
#     171   part = json.loads(line)
#     172   if err := part.get('error'):
#
# File c:\Python311\Lib\site-packages\httpx\_models.py:929, in Response.iter_lines(self)
#     927 decoder = LineDecoder()
#     928 with request_context(request=self._request):
# --> 929     for text in self.iter_text():
#     930         for line in decoder.decode(text):
#     931             yield line
#
# File c:\Python311\Lib\site-packages\httpx\_models.py:916, in Response.iter_text(self, chunk_size)
#     914 chunker = TextChunker(chunk_size=chunk_size)
#     915 with request_context(request=self._request):
# --> 916     for byte_content in self.iter_bytes():
#     917         text_content = decoder.decode(byte_content)
#     918         for chunk in chunker.decode(text_content):
#
# File c:\Python311\Lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File c:\Python311\Lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File c:\Python311\Lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File c:\Python311\Lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File c:\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File c:\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File c:\Python311\Lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File c:\Python311\Lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File c:\Python311\Lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File c:\Python311\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Python311\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
